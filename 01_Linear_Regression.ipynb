# %% [markdown]
# <a href="https://colab.research.google.com/github/ivaibhavi17/Machine-Learning/blob/main/01_Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import linear_model

# %% [markdown]
# linear regression single variable

# %%
dict1 = {
    "area":[2600,3000,3200,3600,4000]
}
dict1
df=pd.DataFrame(dict1)
df['price']=[550000,565000,610000,680000,725000]
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
import matplotlib.pyplot as plt

plt.scatter(df['area'],df['price'],color='red',marker='+')
plt.show()

# %%
reg=linear_model.LinearRegression()
reg.fit(df[['area']],df.price)
# Out:
# LinearRegression()

# %%
reg.predict([[3300]])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([628715.75342466])

# %% [markdown]
# y=mx+b  #line formula
#
# y=price,x=area
#
# price=m(area)+b
#
# m=coef
#
# b=intercept

# %%
reg.coef_
# Out:
# array([135.78767123])

# %%
reg.intercept_
# Out:
# np.float64(180616.43835616432)

# %%
135.78767123*3300+180616.43835616432
# Out:
# 628715.7534151643

# %% [markdown]
# linear regression with multiple variable

# %%
import numpy as np
import pandas as pd
from sklearn import linear_model
dict1 ={
    "area":[2600,3000,3200,3600,4000],
    "bedrooms":[3,4,np.nan,3,5],
    "age":[20,15,18,30,8],
    "price":[550000,565000,610000,680000,725000]

}
df=pd.DataFrame(dict1)
df
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       NaN   18  610000
# 3  3600       3.0   30  680000
# 4  4000       5.0    8  725000

# %% [markdown]
# finf out price
#
# price = m1*area+m2*bedroomds+m3*age+b
#
# m1,m2,m3 are coefficients
#
# b=intercept
#
# y = m1x1 + m2x2 + m3x3 + b

# %%
import math
median_bedrooms=math.floor(df.bedrooms.median())
median_bedrooms
# Out:
# 3

# %%
df.bedrooms = df.bedrooms.fillna(median_bedrooms)
df
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       3.0   18  610000
# 3  3600       3.0   30  680000
# 4  4000       5.0    8  725000

# %%
reg=linear_model.LinearRegression()
reg.fit(df[['area','bedrooms','age']],df.price)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([  143.625, -6762.5  ,   337.5  ])

# %%
reg.intercept_
# Out:
# np.float64(173112.5)

# %%
reg.predict([[3000,3,40]])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([597200.])

# %%
143.625*3000+-6762.5*3+337.5*40+173112.5
# Out:
# 597200.0

# %%
reg.predict([[2500,4,5]])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([506812.5])

# %%
143.625*2500+-6762.5*4+337.5*5+173112.5
# Out:
# 506812.5
